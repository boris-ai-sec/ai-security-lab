# %%
print("RAG Security Review Lab started")
# Out:
# RAG Security Review Lab started

# %%
import sys

print("Python executable:")
print(sys.executable)

print("\nPython version:")
print(sys.version)
# Out:
# Python executable:
# /mnt/c/Users/ggaru/ai-projects/rag-security-review-lab/.venv/bin/python3
#
# Python version:
# 3.13.12 | packaged by Anaconda, Inc. | (main, Feb 24 2026, 16:13:31) [GCC 14.3.0]
